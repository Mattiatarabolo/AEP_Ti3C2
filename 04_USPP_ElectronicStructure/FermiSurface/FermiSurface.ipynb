# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline, BSpline
# %matplotlib widget

# %%
with open("bz_line.dat","r") as f:
    lines = f.readlines()
    xbz = []
    ybz = []
    for line in lines:
        splitline = line.split()
        xbz.append(float(splitline[0]))
        ybz.append(float(splitline[1]))

with open("fermi_line.dat","r") as f:
    lines = f.readlines()
    xfs = []
    yfs = []
    xfstmp = []
    yfstmp = []
    i = 0
    while i < len(lines):
        if lines[i]=="\n":
            xfs.append(np.array(xfstmp))
            yfs.append(np.array(yfstmp))
            xfstmp = []
            yfstmp = []
            i += 2
            continue
        splitline = lines[i].split()
        xfstmp.append(float(splitline[0]))
        yfstmp.append(float(splitline[1]))
        i += 1

# %%
plt.figure(figsize=[10,10])
plt.plot(xbz,ybz,'r')
i = 0
for x in xfs:
    plt.plot(x, yfs[i], 'k')
    i += 1
#plt.ylabel("Energy [eV]")
plt.xlim((-0.7, 0.7))
plt.ylim((-0.7,0.7))
plt.axis('off')
#plt.ylim((min(energies[0])*102/100,4.8748))
#plt.ylim((-15,4.8748))
#plt.xticks(ticks = [0.0000, 0.5730, 0.9038, 1.5654], labels= ["$\Gamma$", "$M$", "$K$", "$\Gamma$"])
#plt.plot([10,10],[min(energies),max(energies)],'r--')
plt.savefig('FermiSurface.pdf')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Out:
# [0.0,
#  0.0057,
#  0.0115,
#  0.0172,
#  0.0229,
#  0.0286,
#  0.0344,
#  0.0401,
#  0.0458,
#  0.0516,
#  0.0573,
#  0.063,
#  0.0688,
#  0.0745,
#  0.0802,
#  0.0859,
#  0.0917,
#  0.0974,
#  0.1031,
#  0.1089,
#  0.1146,
#  0.1203,
#  0.1261,
#  0.1318,
#  0.1375,
#  0.1432,
#  0.149,
#  0.1547,
#  0.1604,
#  0.1662,
#  0.1719,
#  0.1776,
#  0.1833,
#  0.1891,
#  0.1948,
#  0.2005,
#  0.2063,
#  0.212,
#  0.2177,
#  0.2235,
#  0.2292,
#  0.2349,
#  0.2406,
#  0.2464,
#  0.2521,
#  0.2578,
#  0.2636,
#  0.2693,
#  0.275,
#  0.2808,
#  0.2865,
#  0.2922,
#  0.2979,
#  0.3037,
#  0.3094,
#  0.3151,
#  0.3209,
#  0.3266,
#  0.3323,
#  0.3381,
#  0.3438,
#  0.3495,
#  0.3552,
#  0.361,
#  0.3667,
#  0.3724,
#  0.3782,
#  0.3839,
#  0.3896,
#  0.3953,
#  0.4011,
#  0.4068,
#  0.4125,
#  0.4183,
#  0.424,
#  0.4297,
#  0.4355,
#  0.4412,
#  0.4469,
#  0.4526,
#  0.4584,
#  0.4641,
#  0.4698,
#  0.4756,
#  0.4813,
#  0.487,
#  0.4928,
#  0.4985,
#  0.5042,
#  0.5099,
#  0.5157,
# ...
